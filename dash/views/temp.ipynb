# %%
import pandas as pd
import os
from datetime import datetime

# %%
csv_path = '../../..//database/senti/jisilu/'


parm_dict = {'reply': '回帖数',
             'viewers': '浏览数',
             'title': '主题数'}
raw_df = pd.concat([pd.read_csv(os.path.join(csv_path, f), index_col=False) for f in os.listdir(csv_path)],
                   axis=0, ignore_index=True)
# Out:
# /Users/wei/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
file_list = sorted([i for i in os.listdir(csv_path) if i.endswith('txt') ])

# %%
raw_df = pd.concat([pd.read_csv(os.path.join(csv_path, f), index_col=False) for f in file_list[-90:]],
                   axis=0, ignore_index=True)

# %%
raw_df.head()
# Out:
#   topic                               title  \
# 0   NaN                     我现在最担忧的是无病征的确诊者
# 1   NaN                 北京口罩怎么办？网上买不到啊，多谢大家
# 2   NaN              携程大涨，肯德基大涨，外资和我们理解不一样？
# 3    其他             上海，到底是2月3日上班，还是2月10日上班？
# 4    其他  证监会：引导投资者理性、客观分析疫情影响 秉持长期投资、价值投资理念
#
#                                     link  reply  viewers              updated
# 0  https://www.jisilu.cn/question/347785      3      157  2020-01-28 23:54:00
# 1  https://www.jisilu.cn/question/347784      4      166  2020-01-29 01:04:00
# 2  https://www.jisilu.cn/question/347783     16      606  2020-01-29 00:10:00
# 3  https://www.jisilu.cn/question/347782      5      569  2020-01-28 23:25:00
# 4  https://www.jisilu.cn/question/347781      4      300  2020-01-28 22:52:00

# %%
raw_df['date'] = [i[:10] for i in list(raw_df['updated'])]

# %%
rank_df = raw_df.drop_duplicates(subset=['topic', 'title'], keep='first')
rank_df = rank_df.drop(['date'], axis=1).sort_values('reply', ascending=False).head(10)

# %%
rank_df
# Out:
#     topic                   title                                   link  \
# 711    其他  预测明日上证指数开盘跌幅，最接近的赢1金币。  https://www.jisilu.cn/question/348444
# 400    其他  大学教授杨帆警告证监会： 不作为将受历史追责  https://www.jisilu.cn/question/348094
# 17     其他              马上要进隔离病房了！  https://www.jisilu.cn/question/347768
# 99     其他        作为一个商人，口罩钱到底该不该挣  https://www.jisilu.cn/question/347611
# 823    新股  预测明日上证指数开盘跌幅，最接近的赢2金币。  https://www.jisilu.cn/question/348876
# 438    其他          【微博上的爆料】武汉红十字会  https://www.jisilu.cn/question/348051
# 586    其他        大V付费指导，这件事情你们怎么看  https://www.jisilu.cn/question/348227
# 839    其他               今天加仓的请跟帖!  https://www.jisilu.cn/question/348859
# 930    其他              今天巨亏9%，好想哭  https://www.jisilu.cn/question/348760
# 623    其他           股票满仓的进来商量一下对策  https://www.jisilu.cn/question/348182
#
#      reply  viewers              updated
# 711    364     2824  2020-02-03 00:46:00
# 400    166     5173  2020-02-01 00:44:00
# 17     162     2517  2020-01-29 00:49:00
# 99     161     4928  2020-01-29 00:53:00
# 823    141     1377  2020-02-04 00:19:00
# 438    128     5758  2020-02-01 00:58:00
# 586    125     2645  2020-02-02 00:50:00
# 839    115     2559  2020-02-04 00:23:00
# 930    111     5349  2020-02-03 21:56:00
# 623    110     4236  2020-02-01 21:36:00

# %%
rank_df
# Out:
#     topic                   title                                   link  \
# 711    其他  预测明日上证指数开盘跌幅，最接近的赢1金币。  https://www.jisilu.cn/question/348444
# 199    其他              马上要进隔离病房了！  https://www.jisilu.cn/question/347768
# 400    其他  大学教授杨帆警告证监会： 不作为将受历史追责  https://www.jisilu.cn/question/348094
# 99     其他        作为一个商人，口罩钱到底该不该挣  https://www.jisilu.cn/question/347611
# 823    新股  预测明日上证指数开盘跌幅，最接近的赢2金币。  https://www.jisilu.cn/question/348876
# 438    其他          【微博上的爆料】武汉红十字会  https://www.jisilu.cn/question/348051
# 586    其他        大V付费指导，这件事情你们怎么看  https://www.jisilu.cn/question/348227
# 839    其他               今天加仓的请跟帖!  https://www.jisilu.cn/question/348859
# 482    其他         黄冈市卫健委防疫工作中严重渎职  https://www.jisilu.cn/question/347985
# 930    其他              今天巨亏9%，好想哭  https://www.jisilu.cn/question/348760
#
#      reply  viewers              updated
# 711    364     2824  2020-02-03 00:46:00
# 199    224     5339  2020-01-30 00:48:00
# 400    166     5173  2020-02-01 00:44:00
# 99     161     4928  2020-01-29 00:53:00
# 823    141     1377  2020-02-04 00:19:00
# 438    128     5758  2020-02-01 00:58:00
# 586    125     2645  2020-02-02 00:50:00
# 839    115     2559  2020-02-04 00:23:00
# 482    113     7034  2020-02-01 00:34:00
# 930    111     5349  2020-02-03 21:56:00
